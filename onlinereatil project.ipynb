# %%
import pandas as pd

# %%
df = pd.read_csv('online_retail_transactions.csv')
df.head()
# Out:
#   InvoiceNo StockCode      Description  Quantity InvoiceDate  UnitPrice  \
# 0   INV1000      P005       Smartwatch         8  2023-05-05     410.43
# 1   INV1001      P010  USB Flash Drive         1  2023-08-20     650.66
# 2   INV1002      P003           Tablet         8  2023-12-09     191.14
# 3   INV1003      P003           Tablet         9  2023-01-04      70.69
# 4   INV1004      P008            Mouse         7  2023-11-06     520.08
#
#    CustomerID       Country
# 0       10869         India
# 1       10733       Germany
# 2       10081        Canada
# 3       10498  South Africa
# 4       10267  South Africa

# %%
# Check for missing values per column
missing_values = df.isnull().sum()
df
# Out:
#     InvoiceNo StockCode      Description  Quantity InvoiceDate  UnitPrice  \
# 0     INV1000      P005       Smartwatch         8  2023-05-05     410.43
# 1     INV1001      P010  USB Flash Drive         1  2023-08-20     650.66
# 2     INV1002      P003           Tablet         8  2023-12-09     191.14
# 3     INV1003      P003           Tablet         9  2023-01-04      70.69
# 4     INV1004      P008            Mouse         7  2023-11-06     520.08
# ..        ...       ...              ...       ...         ...        ...
# 995   INV1995      P005       Smartwatch         9  2023-09-19     600.74
# 996   INV1996      P004       Headphones         4  2023-05-28     128.53
# 997   INV1997      P002       Smartphone         5  2023-12-13     205.54
# 998   INV1998      P008            Mouse         3  2023-11-26     527.83
# 999   INV1999      P006          Monitor         7  2023-08-10     312.28
#
#      CustomerID       Country
# 0         10869         India
# ...

# %%
# Identify and remove duplicate rows
df_cleaned = df.drop_duplicates()

# %%
# Convert the InvoiceDate column to a proper datetime format
df_cleaned['InvoiceDate'] = pd.to_datetime(df_cleaned['InvoiceDate'])

# %%
df_cleaned
# Out:
#     InvoiceNo StockCode      Description  Quantity InvoiceDate  UnitPrice  \
# 0     INV1000      P005       Smartwatch         8  2023-05-05     410.43
# 1     INV1001      P010  USB Flash Drive         1  2023-08-20     650.66
# 2     INV1002      P003           Tablet         8  2023-12-09     191.14
# 3     INV1003      P003           Tablet         9  2023-01-04      70.69
# 4     INV1004      P008            Mouse         7  2023-11-06     520.08
# ..        ...       ...              ...       ...         ...        ...
# 995   INV1995      P005       Smartwatch         9  2023-09-19     600.74
# 996   INV1996      P004       Headphones         4  2023-05-28     128.53
# 997   INV1997      P002       Smartphone         5  2023-12-13     205.54
# 998   INV1998      P008            Mouse         3  2023-11-26     527.83
# 999   INV1999      P006          Monitor         7  2023-08-10     312.28
#
#      CustomerID       Country
# 0         10869         India
# ...

# %%
# Data Transformation & Exploration
# Create a new column called TotalPrice calculated as Quantity * UnitPrice
df_cleaned['TotalPrice'] = df_cleaned['Quantity'] * df_cleaned['UnitPrice']

# %%
# Determine the number of unique products
unique_products = df_cleaned['StockCode'].nunique()
print("\nNumber of unique products:", unique_products)
# Out:
# Number of unique products: 10
